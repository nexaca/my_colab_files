# %% [markdown]
# <a href="https://colab.research.google.com/github/nexaca/my_colab_files/blob/main/turkish_league_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-01f8a0e5-7605-4775-8283-79680210c973" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-01f8a0e5-7605-4775-8283-79680210c973">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving T1.csv to T1 (1).csv

# %%
football_data = pd.read_csv('T1.csv')

# %% [markdown]
# # TABLO DUZENLEMESI - DATA MINING

# %%
football_data
# Out:
#     Div        Date   Time  ... MaxCAHA AvgCAHH  AvgCAHA
# 0    T1  11/09/2020  18:00  ...    1.99    1.93     1.90
# 1    T1  12/09/2020  15:00  ...    1.90    2.01     1.84
# 2    T1  12/09/2020  15:00  ...    2.06    1.84     2.01
# 3    T1  12/09/2020  18:00  ...    2.04    1.87     1.97
# 4    T1  12/09/2020  18:00  ...    1.98    1.91     1.93
# ..   ..         ...    ...  ...     ...     ...      ...
# 235  T1  07/02/2021  13:00  ...    2.14    1.81     2.04
# 236  T1  07/02/2021  13:00  ...    1.89    2.01     1.84
# 237  T1  07/02/2021  16:00  ...    1.91    2.07     1.78
# 238  T1  08/02/2021  13:00  ...    2.08    1.84     2.00
# 239  T1  08/02/2021  16:00  ...    2.10    1.84     2.02
#
# [240 rows x 105 columns]

# %%
football_data['Date'] = pd.to_datetime(football_data['Date'],dayfirst=True)

# %%
#pd.options("display.max_rows", 500 )

pd.options.display.max_rows = 500

# %%
colnames = football_data.columns.to_list()
colnames
# Out:
# ['Div',
#  'Date',
#  'Time',
#  'HomeTeam',
#  'AwayTeam',
#  'FTHG',
#  'FTAG',
#  'FTR',
#  'HTHG',
#  'HTAG',
#  'HTR',
#  'HS',
#  'AS',
#  'HST',
#  'AST',
#  'HF',
#  'AF',
#  'HC',
#  'AC',
#  'HY',
#  'AY',
#  'HR',
#  'AR',
#  'B365H',
#  'B365D',
#  'B365A',
#  'BWH',
#  'BWD',
#  'BWA',
#  'IWH',
#  'IWD',
#  'IWA',
#  'PSH',
#  'PSD',
#  'PSA',
#  'WHH',
#  'WHD',
#  'WHA',
#  'VCH',
#  'VCD',
#  'VCA',
#  'MaxH',
#  'MaxD',
#  'MaxA',
#  'AvgH',
#  'AvgD',
#  'AvgA',
#  'B365>2.5',
#  'B365<2.5',
#  'P>2.5',
#  'P<2.5',
#  'Max>2.5',
#  'Max<2.5',
#  'Avg>2.5',
#  'Avg<2.5',
#  'AHh',
#  'B365AHH',
#  'B365AHA',
#  'PAHH',
#  'PAHA',
#  'MaxAHH',
#  'MaxAHA',
#  'AvgAHH',
#  'AvgAHA',
#  'B365CH',
#  'B365CD',
#  'B365CA',
#  'BWCH',
#  'BWCD',
#  'BWCA',
#  'IWCH',
#  'IWCD',
#  'IWCA',
#  'PSCH',
#  'PSCD',
#  'PSCA',
#  'WHCH',
#  'WHCD',
#  'WHCA',
#  'VCCH',
#  'VCCD',
#  'VCCA',
#  'MaxCH',
#  'MaxCD',
#  'MaxCA',
#  'AvgCH',
#  'AvgCD',
#  'AvgCA',
# ...

# %%
result_df = football_data[['Date','Time','HomeTeam','AwayTeam','FTHG', 'FTAG', 'FTR', 'B365H',
 'B365D',
 'B365A']]

# %% [markdown]
# # EV SAHIBI GALIP ANALIZI

# %%
home_win = result_df["FTR"] == 'H'
result_df[home_win]['B365H'].value_counts()
# Out:
# 2.37    6
# 1.75    5
# 1.33    5
# 2.10    4
# 1.90    4
# 3.10    4
# 3.40    4
# 1.44    3
# 1.95    3
# 1.45    3
# 1.83    3
# 2.15    3
# 1.72    3
# 2.30    3
# 2.05    3
# 1.50    3
# 2.20    3
# 2.25    2
# 1.66    2
# 2.00    2
# 2.75    2
# 2.80    2
# 2.40    2
# 1.55    2
# 1.40    2
# 3.80    2
# 1.65    2
# 1.36    1
# 4.50    1
# 4.20    1
# 1.25    1
# 5.25    1
# 5.00    1
# 3.75    1
# 2.45    1
# 4.00    1
# 2.35    1
# 3.00    1
# 1.60    1
# 2.62    1
# 2.90    1
# 1.80    1
# 4.33    1
# 1.57    1
# 1.85    1
# 2.87    1
# Name: B365H, dtype: int64

# %%
result_df.loc[result_df['B365H'] == 2.37]
# Out:
#           Date   Time    HomeTeam          AwayTeam  ...  FTR  B365H B365D  B365A
# 5   2020-09-13  15:00  Ankaragucu        Erzurum BB  ...    A   2.37  3.30   2.90
# 81  2020-11-22  10:30   Hatayspor          Rizespor  ...    D   2.37  3.25   3.00
# 112 2020-12-12  13:00    Rizespor            Goztep  ...    H   2.37  3.40   2.87
# 152 2021-01-02  13:00  Alanyaspor        Buyuksehyr  ...    H   2.37  3.50   2.80
# 153 2021-01-02  13:00  Ankaragucu  Yeni Malatyaspor  ...    H   2.37  3.20   3.00
# 198 2021-01-21  16:00  Ankaragucu         Kasimpasa  ...    H   2.37  3.40   2.75
# 215 2021-01-31  10:30  Erzurum BB        Ankaragucu  ...    H   2.37  3.30   2.90
# 224 2021-02-03  13:00  Karagumruk         Gaziantep  ...    H   2.37  3.20   3.00
# 233 2021-02-06  16:00  Fenerbahce       Galatasaray  ...    A   2.37  3.40   2.80
#
# [9 rows x 10 columns]

# %%
result_df.loc[result_df['B365H'] == 1.75]
# Out:
#           Date   Time     HomeTeam        AwayTeam  ...  FTR  B365H B365D  B365A
# 33  2020-10-03  14:00   Buyuksehyr          Goztep  ...    D   1.75  3.80    4.0
# 55  2020-10-25  16:00   Fenerbahce     Trabzonspor  ...    H   1.75  3.80    4.2
# 97  2020-12-04  16:30     Besiktas       Kasimpasa  ...    H   1.75  4.00    4.0
# 122 2020-12-19  13:00  Trabzonspor        Rizespor  ...    H   1.75  3.75    4.5
# 148 2020-12-28  16:00     Besiktas       Sivasspor  ...    H   1.75  3.80    4.2
# 179 2021-01-11  16:00   Alanyaspor       Kasimpasa  ...    A   1.75  3.75    4.5
# 192 2021-01-19  16:00  Trabzonspor       Konyaspor  ...    H   1.75  3.50    4.0
# 227 2021-02-03  16:00    Konyaspor  Genclerbirligi  ...    D   1.75  3.70    4.5
#
# [8 rows x 10 columns]

# %%
#1.33
result_df.loc[result_df['B365H'] == 1.33]
# Out:
#           Date   Time     HomeTeam        AwayTeam  ...  FTR  B365H B365D  B365A
# 89  2020-11-28  13:00   Buyuksehyr     Denizlispor  ...    D   1.33  5.25    8.0
# 173 2021-01-09  16:00  Galatasaray  Genclerbirligi  ...    H   1.33  5.00    9.0
# 188 2021-01-18  16:00   Fenerbahce      Ankaragucu  ...    H   1.33  6.50    6.0
# 195 2021-01-20  16:00  Galatasaray     Denizlispor  ...    H   1.33  5.25    8.0
# 209 2021-01-25  16:00   Fenerbahce     Kayserispor  ...    H   1.33  5.00    8.0
# 214 2021-01-30  16:00   Fenerbahce        Rizespor  ...    H   1.33  5.00    8.5
#
# [6 rows x 10 columns]

# %%
#2.10
result_df.loc[result_df['B365H'] == 2.10].sort_values(by='B365D')
# Out:
#           Date   Time        HomeTeam        AwayTeam  ...  FTR  B365H B365D  B365A
# 121 2020-12-19  10:30          Goztep       Hatayspor  ...    A    2.1  3.20   3.60
# 108 2020-12-09  16:30       Hatayspor      Erzurum BB  ...    H    2.1  3.25   3.50
# 125 2020-12-20  10:30  Genclerbirligi      Ankaragucu  ...    D    2.1  3.25   3.50
# 115 2020-12-13  10:30      Erzurum BB  Genclerbirligi  ...    A    2.1  3.30   3.40
# 22  2020-09-26  14:00          Goztep       Gaziantep  ...    D    2.1  3.40   3.40
# 29  2020-09-28  18:00     Antalyaspor     Denizlispor  ...    H    2.1  3.40   3.40
# 156 2021-01-03  10:30        Rizespor  Genclerbirligi  ...    D    2.1  3.40   3.40
# 170 2021-01-09  10:30       Sivasspor       Gaziantep  ...    H    2.1  3.40   3.40
# 8   2020-09-13  18:00     Trabzonspor        Besiktas  ...    A    2.1  3.50   3.30
# 7   2020-09-13  18:00     Antalyaspor  Genclerbirligi  ...    H    2.1  3.60   3.25
# ...

# %%
#1.90
result_df.loc[result_df['B365H'] == 1.90]
# Out:
#           Date   Time          HomeTeam     AwayTeam  ...  FTR  B365H B365D  B365A
# 47  2020-10-19  18:00       Galatasaray   Alanyaspor  ...    A    1.9   3.4    4.0
# 73  2020-11-08  10:30  Yeni Malatyaspor  Denizlispor  ...    H    1.9   3.4    3.5
# 118 2020-12-14  16:00         Sivasspor  Antalyaspor  ...    D    1.9   3.5    4.0
# 128 2020-12-21  16:00       Antalyaspor  Kayserispor  ...    H    1.9   3.4    4.0
# 160 2021-01-05  13:00         Gaziantep   Ankaragucu  ...    H    1.9   3.6    3.8
# 216 2021-01-31  13:00        Alanyaspor    Sivasspor  ...    H    1.9   3.5    4.0
#
# [6 rows x 10 columns]

# %%
#3.10
result_df.loc[result_df['B365H'] == 3.10].sort_values(by = 'FTR')
# Out:
#           Date   Time        HomeTeam  ... B365H  B365D  B365A
# 180 2021-01-15  16:00  Genclerbirligi  ...   3.1   3.40   2.25
# 31  2020-10-02  18:00       Gaziantep  ...   3.1   3.75   2.15
# 113 2020-12-12  16:00      Ankaragucu  ...   3.1   3.30   2.30
# 165 2021-01-06  13:00  Genclerbirligi  ...   3.1   3.50   2.15
# 172 2021-01-09  13:00     Kayserispor  ...   3.1   3.30   2.30
# 207 2021-01-25  13:00       Kasimpasa  ...   3.1   3.20   2.30
#
# [6 rows x 10 columns]

# %%
#3.40
result_df.loc[result_df['B365H'] == 3.40].sort_values(by = 'FTR')
# Out:
#           Date   Time   HomeTeam     AwayTeam  ...  FTR  B365H B365D  B365A
# 46  2020-10-18  17:00     Goztep   Fenerbahce  ...    A    3.4   3.4   2.10
# 26  2020-09-27  14:00  Konyaspor     Besiktas  ...    H    3.4   3.6   2.05
# 80  2020-11-21  16:00   Besiktas   Buyuksehyr  ...    H    3.4   3.4   2.10
# 107 2020-12-09  15:30     Goztep   Alanyaspor  ...    H    3.4   3.4   2.10
# 162 2021-01-05  16:00  Konyaspor  Galatasaray  ...    H    3.4   3.4   2.10
#
# [5 rows x 10 columns]

# %%
result_df.loc[result_df['B365H'] == 1.44].sort_values(by = 'FTR')
# Out:
#           Date   Time     HomeTeam     AwayTeam  ...  FTR  B365H B365D  B365A
# 19  2020-09-21  18:00   Fenerbahce    Hatayspor  ...    D   1.44  4.50   6.50
# 86  2020-11-23  16:30  Galatasaray  Kayserispor  ...    D   1.44  4.50   6.50
# 13  2020-09-19  17:00   Alanyaspor  Kayserispor  ...    H   1.44  4.20   7.50
# 164 2021-01-06  13:00   Buyuksehyr   Erzurum BB  ...    H   1.44  4.75   6.00
# 208 2021-01-25  16:00   Alanyaspor   Ankaragucu  ...    H   1.44  4.50   5.75
#
# [5 rows x 10 columns]

# %%
result_df.loc[result_df['B365H'] == 1.95].sort_values(by = 'FTR')
# Out:
#           Date   Time     HomeTeam          AwayTeam  ...  FTR  B365H B365D  B365A
# 30  2020-10-02  18:00   Ankaragucu       Kayserispor  ...    A   1.95   3.3   4.00
# 59  2020-10-30  17:00  Trabzonspor         Kasimpasa  ...    A   1.95   3.5   3.75
# 181 2021-01-16  10:30    Konyaspor            Goztep  ...    A   1.95   3.4   3.80
# 193 2021-01-20  13:00    Hatayspor  Yeni Malatyaspor  ...    A   1.95   3.5   3.30
# 212 2021-01-30  10:30    Kasimpasa       Kayserispor  ...    A   1.95   3.6   3.60
# 232 2021-02-06  13:00   Buyuksehyr        Karagumruk  ...    A   1.95   3.7   3.40
# 40  2020-10-17  11:30     Rizespor        Ankaragucu  ...    H   1.95   3.3   4.00
# 82  2020-11-22  13:00       Goztep        Ankaragucu  ...    H   1.95   3.4   3.80
# 104 2020-12-06  13:00  Antalyaspor        Ankaragucu  ...    H   1.95   3.5   3.80
#
# [9 rows x 10 columns]

# %%
sns.countplot(result_df['FTR'][result_df['B365H'] == 1.95])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
result_df.loc[result_df['B365H'] == 1.45].sort_values(by = 'Date')
# Out:
#           Date   Time     HomeTeam   AwayTeam  ...  FTR  B365H B365D  B365A
# 3   2020-09-12  18:00  Galatasaray  Gaziantep  ...    H   1.45  4.50    6.5
# 102 2020-12-05  16:00  Galatasaray  Hatayspor  ...    H   1.45  4.50    6.5
# 168 2021-01-06  16:00     Besiktas   Rizespor  ...    H   1.45  4.75    6.0
#
# [3 rows x 10 columns]

# %%
result_df.loc[result_df['B365H'] == 1.83].sort_values(by = 'Date')
# Out:
#           Date   Time     HomeTeam        AwayTeam  ...  FTR  B365H B365D  B365A
# 16  2020-09-20  14:00    Kasimpasa        Rizespor  ...    H   1.83  3.75    4.0
# 85  2020-11-22  16:00  Trabzonspor      Erzurum BB  ...    H   1.83  3.60    4.2
# 137 2020-12-24  13:00    Sivasspor  Genclerbirligi  ...    H   1.83  3.60    4.0
#
# [3 rows x 10 columns]

# %%
result_df.loc[result_df['B365H'] == 2.15].sort_values(by = 'FTR')
# Out:
#           Date   Time     HomeTeam     AwayTeam  ...  FTR  B365H B365D  B365A
# 143 2020-12-27  13:00  Denizlispor   Ankaragucu  ...    A   2.15   3.4    3.3
# 206 2021-01-24  16:00    Gaziantep    Hatayspor  ...    D   2.15   3.3    3.0
# 4   2020-09-12  18:00       Goztep  Denizlispor  ...    H   2.15   3.3    3.4
# 134 2020-12-23  16:00   Fenerbahce   Buyuksehyr  ...    H   2.15   3.1    3.5
# 238 2021-02-08  13:00    Gaziantep       Goztep  ...    H   2.15   3.1    3.6
#
# [5 rows x 10 columns]

# %%
result_df.loc[result_df['B365H'] == 1.72].sort_values(by = 'FTR')
# Out:
#           Date   Time          HomeTeam  ... B365H  B365D  B365A
# 144 2020-12-27  13:00  Yeni Malatyaspor  ...  1.72   3.60   4.33
# 69  2020-11-07  13:00        Alanyaspor  ...  1.72   3.80   4.50
# 151 2021-01-02  10:30         Sivasspor  ...  1.72   3.50   4.75
# 37  2020-10-04  14:00        Alanyaspor  ...  1.72   3.80   4.50
# 93  2020-11-29  13:00         Kasimpasa  ...  1.72   3.60   4.75
# 190 2021-01-19  13:00            Goztep  ...  1.72   3.75   4.50
#
# [6 rows x 10 columns]

# %%
result_df.loc[result_df['B365H'] == 2.30].sort_values(by = 'FTR')
# Out:
#           Date   Time          HomeTeam  ... B365H  B365D  B365A
# 17  2020-09-20  17:00        Buyuksehyr  ...   2.3    3.4   3.00
# 129 2020-12-21  16:00         Konyaspor  ...   2.3    3.0   3.25
# 11  2020-09-19  11:30    Genclerbirligi  ...   2.3    3.2   3.20
# 70  2020-11-07  13:00        Erzurum BB  ...   2.3    3.2   3.10
# 210 2021-01-29  13:00  Yeni Malatyaspor  ...   2.3    3.6   2.80
# 228 2021-02-04  13:00            Goztep  ...   2.3    3.6   2.80
# 58  2020-10-30  17:00        Karagumruk  ...   2.3    3.0   3.40
# 116 2020-12-13  16:00        Alanyaspor  ...   2.3    3.5   2.90
# 174 2021-01-10  10:30        Karagumruk  ...   2.3    3.3   3.00
#
# [9 rows x 10 columns]

# %%
result_df.loc[result_df['B365H'] == 2.05]
# Out:
#           Date   Time          HomeTeam     AwayTeam  ...  FTR  B365H B365D  B365A
# 48  2020-10-19  18:00    Genclerbirligi  Denizlispor  ...    A   2.05  3.30   3.60
# 91  2020-11-29  10:30        Erzurum BB  Antalyaspor  ...    D   2.05  3.50   3.40
# 123 2020-12-19  13:00  Yeni Malatyaspor    Kasimpasa  ...    H   2.05  3.20   3.60
# 140 2020-12-26  13:00            Goztep   Karagumruk  ...    D   2.05  3.60   3.20
# 163 2021-01-06  10:30       Denizlispor  Kayserispor  ...    A   2.05  3.50   3.60
# 176 2021-01-10  13:00          Rizespor  Denizlispor  ...    D   2.05  3.25   3.75
# 186 2021-01-17  13:00  Yeni Malatyaspor     Rizespor  ...    H   2.05  3.40   3.50
# 187 2021-01-17  16:00          Besiktas  Galatasaray  ...    H   2.05  3.40   3.50
# 234 2021-02-07  10:30        Erzurum BB  Kayserispor  ...    D   2.05  3.30   3.30
#
# [9 rows x 10 columns]

# %%
#1.50
result_df.loc[result_df['B365H'] == 1.50]
# Out:
#           Date   Time     HomeTeam          AwayTeam  ...  FTR  B365H B365D  B365A
# 24  2020-09-26  17:00  Trabzonspor  Yeni Malatyaspor  ...    H    1.5   4.5   5.75
# 127 2020-12-20  16:00     Besiktas        Erzurum BB  ...    H    1.5   4.5   5.75
# 229 2021-02-04  16:00  Trabzonspor       Denizlispor  ...    H    1.5   4.0   6.50
#
# [3 rows x 10 columns]

# %%
#1.50
result_df.loc[result_df['B365H'] == 2.20]
# Out:
#           Date   Time     HomeTeam     AwayTeam  ...  FTR  B365H B365D  B365A
# 28  2020-09-27  17:00  Galatasaray   Fenerbahce  ...    D    2.2   3.4   3.20
# 109 2020-12-11  16:00    Kasimpasa  Denizlispor  ...    H    2.2   3.4   3.20
# 139 2020-12-24  16:00     Rizespor  Antalyaspor  ...    H    2.2   3.4   3.25
# 155 2021-01-02  16:00    Hatayspor    Konyaspor  ...    H    2.2   3.0   3.50
# 171 2021-01-09  13:00       Goztep  Antalyaspor  ...    A    2.2   3.5   3.10
#
# [5 rows x 10 columns]

# %%
#1.50
result_df.loc[result_df['B365H'] == 2.25]
# Out:
#           Date   Time        HomeTeam  ... B365H  B365D  B365A
# 2   2020-09-12  15:00       Sivasspor  ...  2.25   3.50   3.00
# 43  2020-10-17  17:00     Trabzonspor  ...  2.25   3.40   3.10
# 88  2020-11-28  10:30       Gaziantep  ...  2.25   3.25   3.25
# 103 2020-12-06  10:30      Karagumruk  ...  2.25   3.40   3.10
# 133 2020-12-23  13:00      Erzurum BB  ...  2.25   3.00   3.40
# 146 2020-12-28  13:00  Genclerbirligi  ...  2.25   3.25   3.20
# 149 2020-12-29  16:00     Antalyaspor  ...  2.25   3.40   3.00
#
# [7 rows x 10 columns]

# %%
#1.66
result_df.loc[result_df['B365H'] == 1.66]
# Out:
#           Date   Time    HomeTeam     AwayTeam  ...  FTR  B365H B365D  B365A
# 92  2020-11-29  13:00  Alanyaspor    Konyaspor  ...    H   1.66   3.8   5.00
# 183 2021-01-16  13:00   Gaziantep  Kayserispor  ...    H   1.66   4.0   4.75
# 223 2021-02-03  10:30   Sivasspor   Erzurum BB  ...    D   1.66   3.8   5.00
#
# [3 rows x 10 columns]

# %%
#1.66
result_df.loc[result_df['B365H'] == 2.00]
# Out:
#           Date   Time          HomeTeam  ... B365H  B365D  B365A
# 18  2020-09-20  17:00         Gaziantep  ...   2.0    3.4   3.75
# 34  2020-10-03  14:00        Erzurum BB  ...   2.0    3.3   3.75
# 42  2020-10-17  14:00         Konyaspor  ...   2.0    3.2   4.00
# 44  2020-10-18  14:00       Antalyaspor  ...   2.0    3.5   3.60
# 53  2020-10-25  10:30  Yeni Malatyaspor  ...   2.0    3.3   3.80
# 62  2020-11-01  10:30          Rizespor  ...   2.0    3.0   4.20
# 147 2020-12-28  13:00         Konyaspor  ...   2.0    3.3   3.60
# 202 2021-01-24  10:30         Konyaspor  ...   2.0    3.3   3.40
#
# [8 rows x 10 columns]

# %%
#1.66
result_df.loc[result_df['B365H'] == 2.75]
# Out:
#           Date   Time        HomeTeam  ... B365H  B365D  B365A
# 1   2020-09-12  15:00      Karagumruk  ...  2.75    3.6   2.37
# 6   2020-09-13  15:00     Kayserispor  ...  2.75    3.5   2.40
# 36  2020-10-04  11:30     Denizlispor  ...  2.75    3.3   2.50
# 66  2020-11-02  17:00       Hatayspor  ...  2.75    3.0   2.40
# 218 2021-01-31  13:00  Genclerbirligi  ...  2.75    3.3   2.50
#
# [5 rows x 10 columns]

# %%
#1.66
result_df.loc[result_df['B365H'] == 2.80]
# Out:
#           Date   Time    HomeTeam     AwayTeam  ...  FTR  B365H B365D  B365A
# 50  2020-10-24  14:00   Gaziantep    Konyaspor  ...    H    2.8  3.20   2.50
# 72  2020-11-08  10:30  Ankaragucu   Karagumruk  ...    D    2.8  3.30   2.40
# 119 2020-12-15  13:00  Ankaragucu    Hatayspor  ...    H    2.8  3.25   2.50
# 130 2020-12-22  13:00   Hatayspor  Trabzonspor  ...    A    2.8  3.30   2.45
# 235 2021-02-07  13:00  Ankaragucu    Sivasspor  ...    A    2.8  3.30   2.25
#
# [5 rows x 10 columns]

# %%
#1.66
result_df.loc[result_df['B365H'] == 2.40]
# Out:
#           Date   Time          HomeTeam     AwayTeam  ...  FTR  B365H B365D  B365A
# 21  2020-09-26  11:30       Kayserispor   Erzurum BB  ...    A    2.4  3.30   2.87
# 32  2020-10-03  11:30  Yeni Malatyaspor  Antalyaspor  ...    H    2.4  3.25   2.90
# 167 2021-01-06  16:00       Antalyaspor   Karagumruk  ...    H    2.4  3.20   3.00
#
# [3 rows x 10 columns]

# %%
#1.66
result_df.loc[result_df['B365H'] == 1.55]
# Out:
#           Date   Time    HomeTeam   AwayTeam  ...  FTR  B365H B365D  B365A
# 231 2021-02-06  13:00  Alanyaspor   Rizespor  ...    H   1.55   4.0   5.00
# 237 2021-02-07  16:00    Besiktas  Konyaspor  ...    H   1.55   4.0   5.75
#
# [2 rows x 10 columns]

# %%
#1.66
result_df.loc[result_df['B365H'] == 1.40]
# Out:
#           Date   Time     HomeTeam          AwayTeam  ...  FTR  B365H B365D  B365A
# 71  2020-11-07  16:00   Fenerbahce         Konyaspor  ...    A    1.4  4.00    7.5
# 74  2020-11-08  13:00   Buyuksehyr    Genclerbirligi  ...    H    1.4  4.75    7.0
# 114 2020-12-12  16:00   Fenerbahce  Yeni Malatyaspor  ...    A    1.4  4.50    7.0
# 131 2020-12-22  16:00  Galatasaray            Goztep  ...    H    1.4  4.33    8.0
# 154 2021-01-02  16:00  Galatasaray       Antalyaspor  ...    D    1.4  4.50    7.5
#
# [5 rows x 10 columns]

# %%
#1.66
result_df.loc[result_df['B365H'] == 3.80]
# Out:
#           Date   Time    HomeTeam     AwayTeam  ...  FTR  B365H B365D  B365A
# 39  2020-10-04  17:00   Kasimpasa  Galatasaray  ...    H    3.8  3.60   1.95
# 67  2020-11-06  17:00   Gaziantep     Besiktas  ...    H    3.8  3.60   1.90
# 150 2021-01-02  10:30  Erzurum BB    Gaziantep  ...    D    3.8  3.00   2.15
# 197 2021-01-21  13:00  Karagumruk     Besiktas  ...    A    3.8  3.75   1.85
# 211 2021-01-29  16:00   Gaziantep  Galatasaray  ...    A    3.8  3.80   1.85
# 220 2021-02-02  13:00   Hatayspor   Fenerbahce  ...    A    3.8  3.80   1.85
#
# [6 rows x 10 columns]

# %%
#1.66
result_df.loc[result_df['B365H'] == 1.65]
# Out:
#           Date   Time     HomeTeam          AwayTeam  ...  FTR  B365H B365D  B365A
# 64  2020-11-01  16:00     Besiktas  Yeni Malatyaspor  ...    H   1.65   4.0   4.75
# 221 2021-02-02  16:00  Galatasaray        Buyuksehyr  ...    H   1.65   4.1   4.60
#
# [2 rows x 10 columns]

# %%
#1.66
result_df.loc[result_df['B365H'] == 1.36]
# Out:
#           Date   Time    HomeTeam  AwayTeam  ...  FTR  B365H B365D  B365A
# 201 2021-01-23  16:00  Buyuksehyr  Rizespor  ...    D   1.36  4.75    8.5
# 205 2021-01-24  16:00    Besiktas    Goztep  ...    H   1.36  4.50    7.0
#
# [2 rows x 10 columns]

# %%
#1.66
result_df.loc[result_df['B365H'] == 1.25]
# Out:
#          Date   Time     HomeTeam    AwayTeam  ...  FTR  B365H B365D  B365A
# 61 2020-10-31  16:00  Galatasaray  Ankaragucu  ...    H   1.25   6.0   10.0
#
# [1 rows x 10 columns]

# %%
#1.66
result_df.loc[result_df['B365H'] == 4.50]
# Out:
#           Date   Time        HomeTeam     AwayTeam  ...  FTR  B365H B365D  B365A
# 9   2020-09-14  18:00       Hatayspor   Buyuksehyr  ...    H    4.5   3.8   1.72
# 65  2020-11-02  17:00     Antalyaspor   Fenerbahce  ...    A    4.5   4.0   1.61
# 200 2021-01-23  13:00  Genclerbirligi  Trabzonspor  ...    A    4.5   4.0   1.61
# 226 2021-02-03  16:00     Antalyaspor     Besiktas  ...    D    4.5   3.8   1.72
#
# [4 rows x 10 columns]

# %%
result_df.loc[result_df['B365H'] == 4.20]
# Out:
#           Date   Time     HomeTeam    AwayTeam  ...  FTR  B365H B365D  B365A
# 126 2020-12-20  13:00  Denizlispor  Alanyaspor  ...    H    4.2   3.9   1.75
#
# [1 rows x 10 columns]

# %%
result_df.loc[result_df['B365H'] == 1.25]
# Out:
#          Date   Time     HomeTeam    AwayTeam  ...  FTR  B365H B365D  B365A
# 61 2020-10-31  16:00  Galatasaray  Ankaragucu  ...    H   1.25   6.0   10.0
#
# [1 rows x 10 columns]

# %%
result_df.loc[result_df['B365H'] == 5.25]
# Out:
#          Date   Time        HomeTeam    AwayTeam  ...  FTR  B365H B365D  B365A
# 98 2020-12-05  10:30  Genclerbirligi  Alanyaspor  ...    H   5.25   4.0    1.6
#
# [1 rows x 10 columns]

# %%
result_df.loc[result_df['B365H'] ==5.00]
# Out:
#           Date   Time     HomeTeam     AwayTeam  ...  FTR  B365H B365D  B365A
# 120 2020-12-18  16:00   Karagumruk  Galatasaray  ...    H    5.0   4.2    1.6
# 158 2021-01-03  16:00  Kayserispor     Besiktas  ...    A    5.0   4.2    1.6
# 178 2021-01-11  13:00   Erzurum BB   Fenerbahce  ...    A    5.0   4.1    1.6
#
# [3 rows x 10 columns]

# %%
result_df.loc[result_df['B365H'] ==3.75]
# Out:
#           Date   Time     HomeTeam     AwayTeam  ...  FTR  B365H B365D  B365A
# 52  2020-10-24  17:00   Erzurum BB  Galatasaray  ...    A   3.75   3.6   1.85
# 111 2020-12-12  13:00  Kayserispor  Trabzonspor  ...    D   3.75   3.6   1.90
# 124 2020-12-19  16:00    Gaziantep   Fenerbahce  ...    H   3.75   3.5   1.85
# 225 2021-02-03  13:00  Kayserispor   Alanyaspor  ...    D   3.75   3.6   1.90
#
# [4 rows x 10 columns]

# %%
result_df.loc[result_df['B365H'] ==2.45]
# Out:
#           Date   Time        HomeTeam    AwayTeam  ...  FTR  B365H B365D  B365A
# 60  2020-10-31  10:30  Genclerbirligi   Gaziantep  ...    D   2.45   3.3   2.80
# 110 2020-12-12  10:30       Hatayspor  Karagumruk  ...    H   2.45   3.1   2.75
# 135 2020-12-23  16:00       Kasimpasa   Gaziantep  ...    A   2.45   3.2   2.90
#
# [3 rows x 10 columns]

# %%
result_df.loc[result_df['B365H'] ==4.00]
# Out:
#           Date   Time     HomeTeam     AwayTeam  ...  FTR  B365H B365D  B365A
# 12  2020-09-19  14:00  Denizlispor  Trabzonspor  ...    D    4.0   3.5   1.85
# 41  2020-10-17  14:00  Kayserispor    Sivasspor  ...    A    4.0   3.6   1.85
# 175 2021-01-10  13:00   Ankaragucu   Buyuksehyr  ...    A    4.0   3.8   1.83
# 191 2021-01-19  13:00  Kayserispor   Buyuksehyr  ...    H    4.0   3.8   1.80
#
# [4 rows x 10 columns]

# %%
result_df.loc[result_df['B365H'] ==2.35]
# Out:
#          Date   Time   HomeTeam   AwayTeam  FTHG  FTAG FTR  B365H  B365D  B365A
# 83 2020-11-22  13:00  Konyaspor  Kasimpasa     2     1   H   2.35    3.3    2.9

# %%
result_df.loc[result_df['B365H'] ==3.00]
# Out:
#           Date   Time    HomeTeam   AwayTeam  ...  FTR  B365H B365D  B365A
# 15  2020-09-20  11:30  Erzurum BB  Sivasspor  ...    A    3.0   3.1   2.45
# 194 2021-01-20  13:00    Rizespor  Gaziantep  ...    H    3.0   3.4   2.30
#
# [2 rows x 10 columns]

# %%
result_df.loc[result_df['B365H'] ==1.65]
# Out:
#           Date   Time     HomeTeam          AwayTeam  ...  FTR  B365H B365D  B365A
# 64  2020-11-01  16:00     Besiktas  Yeni Malatyaspor  ...    H   1.65   4.0   4.75
# 221 2021-02-02  16:00  Galatasaray        Buyuksehyr  ...    H   1.65   4.1   4.60
#
# [2 rows x 10 columns]

# %%
result_df.loc[result_df['B365H'] ==2.62]
# Out:
#          Date   Time     HomeTeam   AwayTeam  ...  FTR  B365H B365D  B365A
# 23 2020-09-26  14:00    Hatayspor  Kasimpasa  ...    H   2.62   3.3   2.62
# 45 2020-10-18  14:00   Karagumruk  Kasimpasa  ...    D   2.62   3.3   2.62
# 75 2020-11-08  13:00  Kayserispor  Hatayspor  ...    A   2.62   3.2   2.55
# 78 2020-11-21  13:00  Denizlispor  Gaziantep  ...    A   2.62   3.3   2.62
#
# [4 rows x 10 columns]

# %% [markdown]
# # BERABERLIK ANALIZI

# %%
home_win = result_df["FTR"] == 'D'
result_df[home_win]['B365H'].value_counts()
# Out:
# 2.00    6
# 2.30    4
# 2.10    4
# 2.05    4
# 2.70    3
# 3.20    3
# 1.72    2
# 1.44    2
# 3.75    2
# 1.80    2
# 2.75    2
# 2.55    2
# 1.57    2
# 1.75    2
# 1.85    2
# 2.25    1
# 1.66    1
# 3.25    1
# 5.50    1
# 1.53    1
# 4.50    1
# 3.10    1
# 2.37    1
# 1.36    1
# 2.62    1
# 2.80    1
# 2.45    1
# 1.90    1
# 1.33    1
# 3.80    1
# 1.40    1
# 2.20    1
# 3.30    1
# 4.33    1
# 2.15    1
# 1.60    1
# 4.00    1
# Name: B365H, dtype: int64

# %%
result_df.loc[result_df['B365H'] ==2.00].sort_values(by = 'Date', ascending=False)
# Out:
#           Date   Time          HomeTeam  ... B365H  B365D  B365A
# 202 2021-01-24  10:30         Konyaspor  ...   2.0    3.3   3.40
# 147 2020-12-28  13:00         Konyaspor  ...   2.0    3.3   3.60
# 62  2020-11-01  10:30          Rizespor  ...   2.0    3.0   4.20
# 53  2020-10-25  10:30  Yeni Malatyaspor  ...   2.0    3.3   3.80
# 44  2020-10-18  14:00       Antalyaspor  ...   2.0    3.5   3.60
# 42  2020-10-17  14:00         Konyaspor  ...   2.0    3.2   4.00
# 34  2020-10-03  14:00        Erzurum BB  ...   2.0    3.3   3.75
# 18  2020-09-20  17:00         Gaziantep  ...   2.0    3.4   3.75
#
# [8 rows x 10 columns]

# %%
result_df.loc[result_df['B365H'] ==2.00].sort_values(by = 'FTR')

sns.countplot(result_df['FTR'][result_df['B365H'] == 2.00])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
result_df.loc[result_df['B365H'] ==2.30].sort_values(by = 'Date', ascending=False)
# Out:
#           Date   Time          HomeTeam  ... B365H  B365D  B365A
# 228 2021-02-04  13:00            Goztep  ...   2.3    3.6   2.80
# 210 2021-01-29  13:00  Yeni Malatyaspor  ...   2.3    3.6   2.80
# 174 2021-01-10  10:30        Karagumruk  ...   2.3    3.3   3.00
# 129 2020-12-21  16:00         Konyaspor  ...   2.3    3.0   3.25
# 116 2020-12-13  16:00        Alanyaspor  ...   2.3    3.5   2.90
# 70  2020-11-07  13:00        Erzurum BB  ...   2.3    3.2   3.10
# 58  2020-10-30  17:00        Karagumruk  ...   2.3    3.0   3.40
# 17  2020-09-20  17:00        Buyuksehyr  ...   2.3    3.4   3.00
# 11  2020-09-19  11:30    Genclerbirligi  ...   2.3    3.2   3.20
#
# [9 rows x 10 columns]

# %%
sns.countplot(result_df['FTR'][result_df['B365H'] == 2.30])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
result_df.loc[result_df['B365H'] ==2.10].sort_values(by = 'Date', ascending=False)
# Out:
#           Date   Time        HomeTeam        AwayTeam  ...  FTR  B365H B365D  B365A
# 170 2021-01-09  10:30       Sivasspor       Gaziantep  ...    H    2.1  3.40   3.40
# 156 2021-01-03  10:30        Rizespor  Genclerbirligi  ...    D    2.1  3.40   3.40
# 125 2020-12-20  10:30  Genclerbirligi      Ankaragucu  ...    D    2.1  3.25   3.50
# 121 2020-12-19  10:30          Goztep       Hatayspor  ...    A    2.1  3.20   3.60
# 115 2020-12-13  10:30      Erzurum BB  Genclerbirligi  ...    A    2.1  3.30   3.40
# 108 2020-12-09  16:30       Hatayspor      Erzurum BB  ...    H    2.1  3.25   3.50
# 49  2020-10-23  18:00       Kasimpasa          Goztep  ...    D    2.1  3.60   3.20
# 29  2020-09-28  18:00     Antalyaspor     Denizlispor  ...    H    2.1  3.40   3.40
# 22  2020-09-26  14:00          Goztep       Gaziantep  ...    D    2.1  3.40   3.40
# 7   2020-09-13  18:00     Antalyaspor  Genclerbirligi  ...    H    2.1  3.60   3.25
# ...

# %%
sns.countplot(result_df['FTR'][result_df['B365H'] == 2.10])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
result_df.loc[result_df['B365H'] ==2.05].sort_values(by = 'Date', ascending=False)
# Out:
#           Date   Time          HomeTeam     AwayTeam  ...  FTR  B365H B365D  B365A
# 234 2021-02-07  10:30        Erzurum BB  Kayserispor  ...    D   2.05  3.30   3.30
# 186 2021-01-17  13:00  Yeni Malatyaspor     Rizespor  ...    H   2.05  3.40   3.50
# 187 2021-01-17  16:00          Besiktas  Galatasaray  ...    H   2.05  3.40   3.50
# 176 2021-01-10  13:00          Rizespor  Denizlispor  ...    D   2.05  3.25   3.75
# 163 2021-01-06  10:30       Denizlispor  Kayserispor  ...    A   2.05  3.50   3.60
# 140 2020-12-26  13:00            Goztep   Karagumruk  ...    D   2.05  3.60   3.20
# 123 2020-12-19  13:00  Yeni Malatyaspor    Kasimpasa  ...    H   2.05  3.20   3.60
# 91  2020-11-29  10:30        Erzurum BB  Antalyaspor  ...    D   2.05  3.50   3.40
# 48  2020-10-19  18:00    Genclerbirligi  Denizlispor  ...    A   2.05  3.30   3.60
#
# [9 rows x 10 columns]

# %%
sns.countplot(result_df['FTR'][result_df['B365H'] == 2.05])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
result_df.loc[result_df['B365H'] ==2.70].sort_values(by = 'Date', ascending=False)
# Out:
#           Date   Time          HomeTeam     AwayTeam  ...  FTR  B365H B365D  B365A
# 161 2021-01-05  13:00  Yeni Malatyaspor    Sivasspor  ...    D    2.7   3.2   2.70
# 77  2020-11-21  10:30        Karagumruk    Sivasspor  ...    D    2.7   3.3   2.60
# 76  2020-11-08  16:00         Sivasspor  Galatasaray  ...    A    2.7   3.3   2.37
# 10  2020-09-18  18:00  Yeni Malatyaspor       Goztep  ...    D    2.7   3.3   2.50
#
# [4 rows x 10 columns]

# %%
sns.countplot(result_df['FTR'][result_df['B365H'] == 2.70])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
result_df.loc[result_df['B365H'] ==3.20].sort_values(by = 'Date', ascending=False)
# Out:
#           Date   Time          HomeTeam     AwayTeam  ...  FTR  B365H B365D  B365A
# 239 2021-02-08  16:00  Yeni Malatyaspor  Trabzonspor  ...    A    3.2  3.25   2.25
# 177 2021-01-10  16:00         Hatayspor     Besiktas  ...    D    3.2  3.60   2.05
# 95  2020-11-30  16:30       Kayserispor   Karagumruk  ...    D    3.2  3.30   2.20
# 25  2020-09-27  11:30          Rizespor   Alanyaspor  ...    D    3.2  3.40   2.20
#
# [4 rows x 10 columns]

# %%
sns.countplot(result_df['FTR'][result_df['B365H'] == 3.20])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
result_df.loc[result_df['B365H'] ==1.72].sort_values(by = 'Date', ascending=False)
# Out:
#           Date   Time          HomeTeam  ... B365H  B365D  B365A
# 190 2021-01-19  13:00            Goztep  ...  1.72   3.75   4.50
# 151 2021-01-02  10:30         Sivasspor  ...  1.72   3.50   4.75
# 144 2020-12-27  13:00  Yeni Malatyaspor  ...  1.72   3.60   4.33
# 93  2020-11-29  13:00         Kasimpasa  ...  1.72   3.60   4.75
# 69  2020-11-07  13:00        Alanyaspor  ...  1.72   3.80   4.50
# 37  2020-10-04  14:00        Alanyaspor  ...  1.72   3.80   4.50
#
# [6 rows x 10 columns]

# %%
sns.countplot(result_df['FTR'][result_df['B365H'] == 1.72])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
result_df.loc[result_df['B365H'] ==3.75].sort_values(by = 'Date', ascending=False)
# Out:
#           Date   Time     HomeTeam     AwayTeam  ...  FTR  B365H B365D  B365A
# 225 2021-02-03  13:00  Kayserispor   Alanyaspor  ...    D   3.75   3.6   1.90
# 124 2020-12-19  16:00    Gaziantep   Fenerbahce  ...    H   3.75   3.5   1.85
# 111 2020-12-12  13:00  Kayserispor  Trabzonspor  ...    D   3.75   3.6   1.90
# 52  2020-10-24  17:00   Erzurum BB  Galatasaray  ...    A   3.75   3.6   1.85
#
# [4 rows x 10 columns]

# %%
sns.countplot(result_df['FTR'][result_df['B365H'] == 3.75])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # IY-ALT UST ANALIZI

# %%
football_data

# %%
col_titles = football_data.columns.to_list()
col_titles
# Out:
# ['Div',
#  'Date',
#  'Time',
#  'HomeTeam',
#  'AwayTeam',
#  'FTHG',
#  'FTAG',
#  'FTR',
#  'HTHG',
#  'HTAG',
#  'HTR',
#  'HS',
#  'AS',
#  'HST',
#  'AST',
#  'HF',
#  'AF',
#  'HC',
#  'AC',
#  'HY',
#  'AY',
#  'HR',
#  'AR',
#  'B365H',
#  'B365D',
#  'B365A',
#  'BWH',
#  'BWD',
#  'BWA',
#  'IWH',
#  'IWD',
#  'IWA',
#  'PSH',
#  'PSD',
#  'PSA',
#  'WHH',
#  'WHD',
#  'WHA',
#  'VCH',
#  'VCD',
#  'VCA',
#  'MaxH',
#  'MaxD',
#  'MaxA',
#  'AvgH',
#  'AvgD',
#  'AvgA',
#  'B365>2.5',
#  'B365<2.5',
#  'P>2.5',
#  'P<2.5',
#  'Max>2.5',
#  'Max<2.5',
#  'Avg>2.5',
#  'Avg<2.5',
#  'AHh',
#  'B365AHH',
#  'B365AHA',
#  'PAHH',
#  'PAHA',
#  'MaxAHH',
#  'MaxAHA',
#  'AvgAHH',
#  'AvgAHA',
#  'B365CH',
#  'B365CD',
#  'B365CA',
#  'BWCH',
#  'BWCD',
#  'BWCA',
#  'IWCH',
#  'IWCD',
#  'IWCA',
#  'PSCH',
#  'PSCD',
#  'PSCA',
#  'WHCH',
#  'WHCD',
#  'WHCA',
#  'VCCH',
#  'VCCD',
#  'VCCA',
#  'MaxCH',
#  'MaxCD',
#  'MaxCA',
#  'AvgCH',
#  'AvgCD',
#  'AvgCA',
# ...

# %%
iy_df = football_data[['Div',
 'Date',
 'Time',
 'HomeTeam',
 'AwayTeam',
  'B365H',
 'B365D',
 'B365A',
 'FTHG',
 'FTAG',
 'FTR',
 'HTHG',
 'HTAG']]

# %%
iy_df.head(5)
# Out:
#   Div       Date   Time     HomeTeam  ... FTAG  FTR  HTHG  HTAG
# 0  T1 2020-09-11  18:00     Rizespor  ...    2    A     0     0
# 1  T1 2020-09-12  15:00   Karagumruk  ...    0    H     1     0
# 2  T1 2020-09-12  15:00    Sivasspor  ...    2    A     0     1
# 3  T1 2020-09-12  18:00  Galatasaray  ...    1    H     3     0
# 4  T1 2020-09-12  18:00       Goztep  ...    1    H     3     0
#
# [5 rows x 13 columns]

# %%
iy_df['HT.TG'] = iy_df['HTHG']+ iy_df['HTAG']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
iy_df.head(5)
# Out:
#   Div       Date   Time     HomeTeam  ... FTR  HTHG  HTAG  HT.TG
# 0  T1 2020-09-11  18:00     Rizespor  ...   A     0     0      0
# 1  T1 2020-09-12  15:00   Karagumruk  ...   H     1     0      1
# 2  T1 2020-09-12  15:00    Sivasspor  ...   A     0     1      1
# 3  T1 2020-09-12  18:00  Galatasaray  ...   H     3     0      3
# 4  T1 2020-09-12  18:00       Goztep  ...   H     3     0      3
#
# [5 rows x 14 columns]

# %%
ust_1_5 = iy_df['HT.TG'] >1.5

# %%
iy_df[ust_1_5].sort_values(by = 'Date')
# Out:
#     Div       Date   Time          HomeTeam  ... FTR  HTHG  HTAG  HT.TG
# 3    T1 2020-09-12  18:00       Galatasaray  ...   H     3     0      3
# 4    T1 2020-09-12  18:00            Goztep  ...   H     3     0      3
# 10   T1 2020-09-18  18:00  Yeni Malatyaspor  ...   D     1     1      2
# 21   T1 2020-09-26  11:30       Kayserispor  ...   A     0     2      2
# 24   T1 2020-09-26  17:00       Trabzonspor  ...   H     3     0      3
# 37   T1 2020-10-04  14:00        Alanyaspor  ...   H     4     0      4
# 40   T1 2020-10-17  11:30          Rizespor  ...   H     2     3      5
# 46   T1 2020-10-18  17:00            Goztep  ...   A     1     2      3
# 47   T1 2020-10-19  18:00       Galatasaray  ...   A     1     1      2
# 48   T1 2020-10-19  18:00    Genclerbirligi  ...   A     0     2      2
# 51   T1 2020-10-24  17:00        Buyuksehyr  ...   H     4     1      5
# 52   T1 2020-10-24  17:00        Erzurum BB  ...   A     1     1      2
# ...
