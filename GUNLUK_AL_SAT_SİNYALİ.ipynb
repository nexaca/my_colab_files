# %% [markdown]
# <a href="https://colab.research.google.com/github/nexaca/my_colab_files/blob/main/GUNLUK_AL_SAT_S%C4%B0NYAL%C4%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import time
from subprocess import run,Popen,call

#import telegram-send
#telegram_send.send(messages=["Wow that was easy!"])

currName =str(input('CURRENCY   :\t')).strip()
target = float(input('TARGET PRICE:\t'))
print('interval must be bigger than 3 seconds')
interval = int(input('SET YOUR INTERVAL (seconds) :\t'))

while True:
    resp = requests.get(f'https://api.coinbase.com/v2/prices/{currName}-USD/spot')
    #data = json.dumps(resp.json())
    data = resp.json()

    currency = data['data']['base']
    price = data['data']['amount']
    timestamp = time.ctime()

    print('='*50)
    print(f'Time        : {timestamp}')
    print(f'Currency    : {currency}')
    print(f'Price       : {price} $')

    if float(price) > target:
        print('Sell')
        #telegram_send.send(messages=["You Can Sell Now!"])
        command = ['telegram-send',f'Target price reached : {target} . You Can Sell Your {currName} Right Now!']
        run(command)
        break

    else:
        diff = round(target - float(price) , 2)
        diffPercent = round(100*(1 - (float(price) / target)) , 2)
        print('Status      : Hold')
        print(f'Diff        : -{diff}')
        print(f'Diff Percent: -%{diffPercent}')
        #telegram_send.send(messages=[f"Hold Your {currName}!"])
        #command = ['telegram-send',f'Hold your {currName}']
        #run(command)
        pass

    print('='*50)
    time.sleep(interval)
# Out:
# CURRENCY   :	FIL
# TARGET PRICE:	95
# interval must be bigger than 3 seconds
# SET YOUR INTERVAL (seconds) :	15
# ==================================================
# Time        : Thu Mar 25 10:22:31 2021
# Currency    : FIL
# Price       : 93.1593 $
# Status      : Hold
# Diff        : -1.84
# Diff Percent: -%1.94
# ==================================================
# ==================================================
# Time        : Thu Mar 25 10:22:46 2021
# Currency    : FIL
# Price       : 93.1593 $
# Status      : Hold
# Diff        : -1.84
# Diff Percent: -%1.94
# ==================================================
# ==================================================
# Time        : Thu Mar 25 10:23:01 2021
# Currency    : FIL
# Price       : 93.1593 $
# Status      : Hold
# Diff        : -1.84
# Diff Percent: -%1.94
# ==================================================
# ==================================================
# Time        : Thu Mar 25 10:23:17 2021
# Currency    : FIL
# Price       : 93.0001 $
# Status      : Hold
# Diff        : -2.0
# Diff Percent: -%2.11
# ==================================================
# ==================================================
# Time        : Thu Mar 25 10:23:32 2021
# Currency    : FIL
# Price       : 93.0001 $
# Status      : Hold
# Diff        : -2.0
# Diff Percent: -%2.11
# ==================================================
# ==================================================
# Time        : Thu Mar 25 10:23:47 2021
# Currency    : FIL
# Price       : 93.024 $
# Status      : Hold
# Diff        : -1.98
# Diff Percent: -%2.08
# ==================================================
# ==================================================
# Time        : Thu Mar 25 10:24:02 2021
# Currency    : FIL
# Price       : 93.024 $
# Status      : Hold
# Diff        : -1.98
# Diff Percent: -%2.08
# ==================================================
# ==================================================
# Time        : Thu Mar 25 10:24:17 2021
# Currency    : FIL
# Price       : 93.024 $
# Status      : Hold
# Diff        : -1.98
# Diff Percent: -%2.08
# ==================================================
# ==================================================
# Time        : Thu Mar 25 10:24:32 2021
# Currency    : FIL
# Price       : 92.9142 $
# Status      : Hold
# Diff        : -2.09
# Diff Percent: -%2.2
# ==================================================
# ==================================================
# Time        : Thu Mar 25 10:24:47 2021
# Currency    : FIL
# Price       : 92.9142 $
# Status      : Hold
# Diff        : -2.09
# Diff Percent: -%2.2
# ==================================================
